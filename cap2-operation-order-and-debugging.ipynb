# %% [markdown]
# # Assignment instructions
#
# We have variables below. Variable names must be meaningful and easy to read. Only lowercase letters, followed by underscore if there is more than one word. Python keywords are prohibited.

# %%
number = 5
text = "Hello"

# %% [markdown]
# # Operation order
#
# Just like math: PEMDAS. In order: parenthesis, exponentiation, multiplication, division, addition, subtraction.

# %%
print(5 + (5 * 5) ** 32 * 40 / 50 + 35 - 40)
# Out:
# 4.336808689942018e+44

# %% [markdown]
# # Comments

# %%
# Just use this, but in a purposeful way.
""" Or this, to
multiple line
comments. """
# Out:
# ' Or this, to\nmultiple line\ncomments. '

# %% [markdown]
# # Debugging and errors
#
# There is SyntaxError, that will be catched by the interpreter as soon as possible and stops the running code. They are problems involving syntax, structure, often typing missing.

# %%
8)
# Out:
#   Cell In[8], line 1
#     8)
#      ^
# SyntaxError: unmatched ')'

# %% [markdown]
# There are also runtime errors, erros that only occur when the interpreter are executing the instructions. For instance, below, we have ZeroDivisionError. This is an exception, something that shouldn't occur.

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# And of course, there are also semantic errors. More subtle errors that often involves the logic, as you can see below:

# %%
x = 5

# Code generated by AI
if x > 10 or x < 20:
    print(str(x) + " is between 10 and 20")
# Out:
# 5 is between 10 and 20

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Exercise 2.1
# Repetindo o meu conselho do capítulo anterior, sempre que você aprender um recurso novo, você deve testá-lo no modo interativo e fazer erros de propósito para ver o que acontece.
#
# - Vimos que `n = 42` é legal. E `42 = n?`
# - Ou `x = y = 1`?
# - Em algumas linguagens, cada instrução termina em um ponto e vírgula `;`. O que acontece se você puser um ponto e vírgula no fim de uma instrução no Python?
# - E se puser um ponto no fim de uma instrução?
# - Em notação matemática é possível multiplicar `x` e `y` desta forma: `xy`. O que acontece se você tentar fazer o mesmo no Python?
#
# __EN:__
# Repeating my advice from the previous chapter, whenever you learn a new feature, you should test it in interactive mode and make deliberate mistakes to see what happens.
#
# - We saw that n = 42 is legal. How about 42 = n?
# __Answer:__ 42 = n returns SyntaxError, because the interpreter is trying to assign a variable starting with a number and this is prohibited.
#
# - What about x = y = 1?
# __Answer:__ This seems to be totally fine. Nothing wrong occurs.
#
# - In some languages, each statement ends with a semicolon ;. What happens if you put a semicolon at the end of a statement in Python?
# __Answer:__ This also seems to be fine, the interpreter didn't raise an error.
#
# - What if you put a period at the end of a statement?
# __Answer:__ This raises an SyntaxError.
#
# - In mathematical notation, it is possible to multiply x and y like this: xy. What happens if you try the same in Python?
# __Answer:__ This raises an NameError because there isn't any variable called xy.

# %%
42 = n
# Out:
#   Cell In[15], line 1
#     42 = n
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
x = y = 1
print("x: " + str(x))
print("y: " + str(y))

y = 5
print("x: " + str(x))
# Out:
# x: 1
# y: 1
# x: 1

# %%
x = "teste";

# %%
X = "teste".
# Out:
#   Cell In[31], line 1
#     X = "teste".
#                 ^
# SyntaxError: invalid syntax

# %%
x = 2
y = 3
print("x * y: " + str(x * y))
print("xy: " + str(xy))
# Out:
# x * y: 6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       2 y = 3
#       3 print("x * y: " + str(x * y))
# ----> 4 print("xy: " + str(xy))
#
# NameError: name 'xy' is not defined

# %% [markdown]
# ## Exercise 2.2
#
# Pratique o uso do interpretador do Python como em uma calculadora:
# 1. O volume de uma esfera com raio `r` é $\frac{{4\pi r^3 }}{3}$. Qual é o volume de uma esfera com raio 5?
# 2. Suponha que o preço da capa de um livro seja `R24,95`, mas as livrarias recebem um desconto de `40%`. O transporte custa `R300` para o primeiro exemplar e `75` centavos para cada exemplar adicional. Qual é o custo total de atacado para 60 cópias?
# 3. Se eu sair da minha casa às `6:52` e correr `1` quilômetro a um certo passo (`8min15s por quilômetro`), então `3` quilômetros a um passo mais rápido (`7min12s por quilômetro`) e `1` quilômetro no mesmo passo usado em primeiro lugar, que horas chego em casa para o café da manhã?
#
# __EN:__
# Practice using the Python interpreter as a calculator:
#
# 1. The volume of a sphere with radius r is $\frac{{4\pi r^3 }}{3}$. What is the volume of a sphere with radius 5?
# __Answer:__ sphere volume: 523.5833333333334
#
# 2. Suppose the price of a book cover is R24.95, but bookstores receive a 40% discount. Shipping costs R300 for the first copy and 75 cents for each additional copy. What is the total wholesale cost for 60 copies?
# __Answer:__ The amount is 1242.4499999999998
#
# 3. If I leave my house at 6:52 and run 1 kilometer at a certain pace (8 minutes 15 seconds per kilometer), then 3 kilometers at a faster pace (7 minutes 12 seconds per kilometer), and 1 kilometer at the same pace as the first, what time do I arrive home for breakfast?
# __Answer:__ 7:30

# %%
sphere_volume = ((4 * 3.1415 * (5 ** 3)) / 3)
print("sphere volume: " + str(sphere_volume))
# Out:
# sphere volume: 523.5833333333334

# %%
book_cover = 24.95
bookstore_discount = 0.4
print(book_cover - (bookstore_discount * book_cover))
shipping_costs = 300
shipping_costs_additional = 0.75
copies = 60
print("The amount is " + str((copies * (book_cover - (book_cover * bookstore_discount))) + shipping_costs + (shipping_costs_additional * (copies - 1))))
# Out:
# 14.969999999999999
# The amount is 1242.4499999999998

# %%
first_pace = 2 * ((8 * 60) + 15)
second_pace = 3 * ((7 * 60) + 12)
total_secs = first_pace + second_pace
total_minutes = total_secs / 60
print(total_minutes)
print(60 - 52)
print("7:30")
# Out:
# 38.1
# 8
# 7:30
